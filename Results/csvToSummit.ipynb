# %%
import pandas as pd
import numpy as np

df = pd.read_csv('agree100.csv',index_col='_unit_id')
df[['id_rel','agree']]
# Out:
#             _golden _unit_state  _trusted_judgments  _last_judgment_at id_rel  \
# _unit_id
# 1293280368    False   finalized                   3  7/5/2017 21:33:23  5 5 5
# 1293280372    False   finalized                   3  7/5/2017 20:24:52  5 5 5
#
#             sentena_sem_relao  sentena_sem_relao:confidence   txt_rel  \
# _unit_id
# 1293280368              False                           1.0  de de de
# 1293280372              False                           1.0  em em em
#
#                                                          html id_ent1 id_ent2  \
# _unit_id
# 1293280368  <span data-id='0'>A</span> <span data-id='1'>e...       7       3
# 1293280372  <span data-id='0'class='entity'>Jennifer_Leona...       4       6
#
#            id_rel_gold id_sent              id_txt sentena_sem_relao_gold  \
# _unit_id
# 1293280368         NaN      S8  CIENCIA_2002_22010                    NaN
# 1293280372         NaN     S13  CIENCIA_2002_22010                    NaN
#
# ...

# %%
with open("/home/pucrspln/summit2csv/Summ-it++ Corpus and csv conversions/Summ-it++v3.txt", "r", encoding = "utf8") as summit, open("Summ-it++v3_relation_gold.txt", "w") as saida:

    for line in summit:
            
        if line.find("#begin") >= 0:
            columns = line.split('/')
            idText = columns[7]
        
        columns = line.split('\t')
        
        if len(columns) >= 6:
            idSent = columns[0]
            idToken = columns[1]
            relations = df.loc[(df['id_txt'] == idText) & (df['id_sent'] == idSent) & ((df['id_ent1'] == idToken) | (df['id_ent2'] == idToken))]
            
            

        #if line == "\n":
            
        
        #line = '\t'.join(vector)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-37-6c343587e947> in <module>()
#      13             idToken = columns[1]
#      14             df.loc[(df['id_txt'] == idText) & (df['id_sent'] == idSent) & ((df['id_ent1'] == idToken) | (df['id_ent2'] == idToken))]
# ---> 15             palavras[int(columns[1])] = [columns[2], columns[7], columns[8]]
#      16             if columns[7].find("(ORG") >= 0 or columns[7].find("(PLC") >= 0 or columns[7].find("(PER") >= 0:
#      17                 entidades[int(columns[1])] = columns[7]
#
# NameError: name 'palavras' is not defined
